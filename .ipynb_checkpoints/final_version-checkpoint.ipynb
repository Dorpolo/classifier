# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import average_precision_score, auc, roc_curve, log_loss
from catboost import CatBoostClassifier
from configs import config_vars

class ModelExplained:
    def __init__(self):
        self.feature_list = config_vars['feature_list']
        self.data = config_vars['data']
        self.model_features = None
        self.category_features = None
        self.X_test = None
        self.y_test = None
        self.X_train = None
        self.y_train = None
        self.trained_model = None

    @staticmethod
    def extract_domain(x) -> str:
        return x[(x.index('@') + 1):x.index('.')]

    # add imputation feature
    @staticmethod
    def data_imputation(dataframe, features: dict):
        for key, value in features.items():
            if value['model']:
                if value['type'] == 'numeric':
                    param = dataframe[key].median()
                else:
                    param = dataframe[key].mode()[0]
                dataframe[key] = dataframe[key].fillna(param)
        return dataframe

    def feature_extraction(self) -> bool:
        self.model_features = [key for key, value in self.feature_list.items() if value['model']]
        self.category_features = [key for key, value in self.feature_list.items()
                                  if value['type'] == 'string' and key != 'y' and value['model']]
        return True

    def data_preps(self) -> bool:
        self.data['y'] = [0 if item == 'approved' else 1 for item in self.data['status'].to_list()]
        self.data['email_anoni'] = [item for item in self.data['email_anoni'].to_list()]
        full_data = self.data_imputation(self.data, self.feature_list)
        X = full_data
        y = full_data['y']
        self.X_train, self.X_test, self.y_train, self.y_test = train_test_split(X, y, test_size=0.2, random_state=0)
        self.X_train = self.X_train[self.model_features]
        return True

    def param_model_training(self, learning_rate: float, depth: int, trees: int) -> tuple:
        X = self.X_train
        y = self.y_train
        X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=0)

        clf = CatBoostClassifier(
            iterations=trees,
            learning_rate=learning_rate,
            depth=depth,
        )

        clf.fit(X_train, y_train,
                cat_features=self.category_features,
                eval_set=(X_val, y_val),
                verbose=False)

        return clf, clf.predict(data=X_val), clf.predict_proba(data=X_val), y_val

    def hyper_params(self) -> dict:
        hyper_params = {
            'learning_rate': [],
            'depth': [],
            'trees': [],
            'log_loss': [],
            'prauc': [],
            'auc': []
        }
        lr_range = np.arange(0.16, 0.19, 0.01)
        depth_range = range(6, 9)
        tree_range = [1]
        for lr in lr_range:
            for d in depth_range:
                t = tree_range[0]
                clf, predicted_prob, predicted_class, y_true = self.param_model_training(lr, d, t)
                prauc = round(average_precision_score(y_true, predicted_prob, pos_label=1), 5)
                fpr, tpr, thresholds = roc_curve(y_true, predicted_prob, pos_label=1)
                kpi_auc = round(auc(fpr, tpr), 5)
                logloss = round(log_loss(y_true, predicted_prob), 5)
                hyper_params['learning_rate'].append(lr)
                hyper_params['depth'].append(d)
                hyper_params['trees'].append(t)
                hyper_params['log_loss'].append(logloss)
                hyper_params['prauc'].append(prauc)
                hyper_params['auc'].append(kpi_auc)
        return hyper_params

    def main_model_training(self):
        params_data = self.hyper_params()
        df_params = pd.DataFrame(params_data)
        df_params.to_csv('data/plots/hyper_params.csv')
        res = df_params[df_params.prauc == max(df_params.prauc)].iloc[0]
        learning_rate, depth, trees = res[0], res[1], res[2]

        clf = CatBoostClassifier(
            iterations=trees,
            learning_rate=learning_rate,
            depth=depth,
        )

        trained_model = clf.fit(
            self.X_train,
            self.y_train,
            cat_features=self.category_features,
            verbose=False
        )
        self.trained_model = trained_model
        return True

    @staticmethod
    def get_approval_rate(th, scores: list) -> float:
        th_class = [1 if item[1] > th else 0 for item in scores]
        results = {i: th_class.count(i) for i in set(th_class)}
        keys = [item for item in results.keys()]
        if len(keys) == 2:
            return results[0]*100.0/len(th_class)
        else:
            return 100 if 0 in keys else 0

    def find_threshold(self, th, required_approval_rate: float = 0.9) -> bool:
        clf = self.trained_model
        if clf is not None:
            model_probs = self.trained_model.predict_proba(self.X_test[self.model_features])
            approval_rate = self.get_approval_rate(th, model_probs.tolist())
            th_l, app_rate_l = [th], [approval_rate]
            while abs(approval_rate - required_approval_rate) > 0.15 and th < 1:
                th += 0.001
                approval_rate = self.get_approval_rate(th, model_probs)
                th_l.append(th)
                app_rate_l.append(approval_rate)
            df = pd.DataFrame({'approval_rate': app_rate_l, 'threshold': th_l})
            df.to_csv('data/plots/threshold.csv')
            return True
        else:
            return False

    def update_test_dataset(self):
        try:
            df_main = pd.DataFrame(self.X_test)
            predicted_results = self.trained_model.predict_proba(data=self.X_test[self.model_features]).tolist()
            df_main['model_score_0'] = [item[0] for item in predicted_results]
            df_main['model_score_1'] = [item[1] for item in predicted_results]
            df_main.to_csv('data/plots/dataset_test_beta.csv')
        except Exception as e:
            print(e)

    def main(self):
        self.feature_extraction()
        self.data_preps()
        self.main_model_training()
        self.find_threshold(th=0.2)
        self.update_test_dataset()

# %%
from sklearn import metrics
from matplotlib import pyplot 
df_f = pd.read_csv("data/plots/dataset_test.csv")
y = np.array(df_f['y'])
pred = np.array(df_f['model_score_1'])
fpr, tpr, thresholds = metrics.roc_curve(y, pred)       
pyplot.plot(fpr, tpr, marker='.', label='Logistic')
precision, recall, _ = metrics.precision_recall_curve(y, pred)
precision
# plot the model precision-recall curve
pyplot.plot(recall, precision, marker='.', label='CatBoost')
# axis labels
pyplot.xlabel('Recall')
pyplot.ylabel('Precision')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
from catboost.utils import get_roc_curve
get_roc_curve(y, 
              pred,
              thread_count=-1,
              plot=True)
#df_f.head(10)
# fpr, tpr, thresholds = metrics.roc_curve(y, pred, pos_label=2)
# Out:
# ---------------------------------------------------------------------------
# CatBoostError                             Traceback (most recent call last)
# <ipython-input-93-9989710f8f52> in <module>
#      18 pyplot.show()
#      19 from catboost.utils import get_roc_curve
# ---> 20 get_roc_curve(y,
#      21               pred,
#      22               thread_count=-1,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/catboost/utils.py in get_roc_curve(model, data, thread_count, plot)
#     358         data = [data]
#     359     if not isinstance(data, list):
# --> 360         raise CatBoostError('data must be a catboost.Pool or list of pools.')
#     361     for pool in data:
#     362         if not isinstance(pool, Pool):
#
# CatBoostError: data must be a catboost.Pool or list of pools.

# %%
metrics.roc_auc_score(y, pred)
# Out:
# 0.9390861368485336

# %%
df_prauc = pd.DataFrame({'precision': precision, 'recall': recall})
df_prauc.to_csv('data/plots/dataset_prauc.csv')

# %%
df_f
# Out:
#        Unnamed: 0   order_id    status                       email_anoni  \
# 0          142106  184890681  approved                WUGvsUBwmS@mail.ru
# 1           44075  194104316  approved            UTTQIw54ghcT@gmail.com
# 2          165921  171029114  approved  yrfMfTzHkvmr@personal_domain.com
# 3           99275  214717189  approved         vkWr3e11u98x@yahoo.com.br
# 4           56031  120364820  approved            oTH5Z0HLbD@hotmail.com
# ...           ...        ...       ...                               ...
# 37995       53224  161565242  approved              GlVgCwmFbf@gmail.com
# 37996      188004  201317591  declined                5dGZxLp1@gmail.com
# 37997       15105  146740464  approved              gHnqp40q65@gmail.com
# 37998      116784  106409638  approved        NsbjN2ApMLqBb0@hotmail.com
# 37999       29750  140058642  approved          ufbUUSNTXnj9L1@gmail.com
#
#       billing_country_code shipping_country_code shipping_method  created_at  \
# 0                       US                    US      value_2169  2017-04-30
# 1                       US                    US       value_522  2017-05-25
# 2                       US                    US      value_1059  2017-03-22
# 3                       BR                    BR      value_1645  2017-07-14
# 4                       CA                    CA      value_1010  2016-11-04
# ...                    ...                   ...             ...         ...
# 37995                   BR                    US       value_585  2017-02-21
# 37996                   AL                    AL      value_1344  2017-06-16
# 37997                   NZ                    NZ      value_1653  2017-01-08
# 37998                   AU                    AU      value_2185  2016-09-23
# 37999                   TW                    TW      value_1938  2016-12-19
#
#        total_spent currency_code  ... V5_merchant_age  V6_avs_result  \
# 0       288.950000           USD  ...             0.0    Unsupported
# 1       115.000000           USD  ...           118.0      Zip Match
# 2        56.990000           USD  ...             1.0    Unsupported
# 3       437.102606           BRL  ...             0.0    Unsupported
# 4        81.600000           USD  ...             1.0      Zip Match
# ...            ...           ...  ...             ...            ...
# 37995   197.460000           USD  ...             1.0        Missing
# 37996   397.651512           GBP  ...             0.0        Missing
# 37997   149.990000           USD  ...             0.0        Missing
# 37998   106.000000           USD  ...             0.0    Unsupported
# 37999   152.785146           TWD  ...             1.0    Unsupported
#
#        V7_bill_ship_name_match  V8_ip  V9_cookie  V10_cookie V11_cookie  y  \
# 0                           FL    0.0       18.0   13.034492   0.012836  0
# 1                           FL    0.0        0.0    0.429963   1.773900  0
# 2                           FL    0.0        0.0    0.564402   1.773900  0
# 3                     NO_MATCH    0.0        0.0   55.650151   1.773900  0
# 4                           FL    0.0        0.0    0.108542   1.773900  0
# ...                        ...    ...        ...         ...        ... ..
# 37995                       FL    0.0        0.0    2.857796   1.773900  0
# 37996                       FL    3.0        0.0   10.179641   1.773900  1
# 37997                       FL    0.0        0.0    0.584036   1.773900  0
# 37998                       FL    0.0       21.0    1.023404   0.010081  0
# 37999                       FL    0.0       16.0    0.783340   0.554572  0
#
#        model_score_0  model_score_1
# 0           0.305585       0.694415
# 1           0.990976       0.009024
# 2           0.678776       0.321224
# 3           0.541354       0.458646
# 4           0.996037       0.003963
# ...              ...            ...
# 37995       0.990148       0.009852
# 37996       0.245690       0.754310
# 37997       0.993005       0.006995
# 37998       0.982276       0.017724
# 37999       0.995364       0.004636
#
# [38000 rows x 25 columns]

# %%
from classifier import ModelExplained

obj = ModelExplained()
obj.main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# _catboost.pyx in _catboost.get_float_feature()
#
# _catboost.pyx in _catboost._FloatOrNan()
#
# _catboost.pyx in _catboost._FloatOrNanFromString()
#
# TypeError: Cannot convert 'b'US'' to float
#
# During handling of the above exception, another exception occurred:
#
# CatBoostError                             Traceback (most recent call last)
# <ipython-input-57-6a9404108ea6> in <module>
#       2
#       3 obj = ModelExplained()
# ----> 4 obj.main()
#
# ~/Desktop/private/riskitest/classifier.py in main(self)
#     160         self.data_preps()
#     161         self.main_model_training()
# --> 162         self.find_threshold(th=0.2)
#     163         self.update_test_dataset()
#
# ~/Desktop/private/riskitest/classifier.py in find_threshold(self, th, required_approval_rate)
#     133         if clf is not None:
#     134             model_probs = self.trained_model.predict_proba(self.X_test[self.model_features])
# --> 135             approval_rate = self.get_approval_rate(th, model_probs.tolist())
#     136             th_l, app_rate_l = [th], [approval_rate]
#     137             while abs(approval_rate - required_approval_rate) > 0.15 and th < 1:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/catboost/core.py in predict_proba(self, data, ntree_start, ntree_end, thread_count, verbose)
#    4631                 with probability for every class for each object.
#    4632         """
# -> 4633         return self._predict(data, 'Probability', ntree_start, ntree_end, thread_count, verbose, 'predict_proba')
#    4634
#    4635
#
# ~/opt/anaconda3/lib/python3.8/site-packages/catboost/core.py in _predict(self, data, prediction_type, ntree_start, ntree_end, thread_count, verbose, parent_method_name)
#    2088         if verbose is None:
#    2089             verbose = False
# -> 2090         data, data_is_single_object = self._process_predict_input_data(data, parent_method_name, thread_count)
#    2091         self._validate_prediction_type(prediction_type)
#    2092
#
# ~/opt/anaconda3/lib/python3.8/site-packages/catboost/core.py in _process_predict_input_data(self, data, parent_method_name, thread_count, label)
#    2068         is_single_object = _is_data_single_object(data)
#    2069         if not isinstance(data, Pool):
# -> 2070             data = Pool(
#    2071                 data=[data] if is_single_object else data,
#    2072                 label=label,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/catboost/core.py in __init__(self, data, label, cat_features, text_features, embedding_features, column_description, pairs, delimiter, has_header, ignore_csv_quoting, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#     586                     )
#     587
# --> 588                 self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#     589         super(Pool, self).__init__()
#     590
#
# ~/opt/anaconda3/lib/python3.8/site-packages/catboost/core.py in _init(self, data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#    1100             baseline = np.reshape(baseline, (samples_count, -1))
#    1101             self._check_baseline_shape(baseline, samples_count)
# -> 1102         self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#    1103
#    1104
#
# _catboost.pyx in _catboost._PoolBase._init_pool()
#
# _catboost.pyx in _catboost._PoolBase._init_pool()
#
# _catboost.pyx in _catboost._PoolBase._init_features_order_layout_pool()
#
# _catboost.pyx in _catboost._set_features_order_data_pd_data_frame()
#
# _catboost.pyx in _catboost.create_num_factor_data()
#
# _catboost.pyx in _catboost.get_float_feature()
#
# CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=4]="US": Cannot convert 'b'US'' to float

# %%
metric.get_roc_curve(y, 
              pred,
              thread_count=-1,
              plot=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-1b86ea9802d5> in <module>
# ----> 1 metric.get_roc_curve(y,
#       2               pred,
#       3               thread_count=-1,
#       4               plot=True)
#
# NameError: name 'metric' is not defined

# %%
obj.trained_model.predict_proba(obj.X_test[obj.model_features])
# Out:
# array([[0.64111852, 0.35888148],
#        [0.89955341, 0.10044659],
#        [0.57348888, 0.42651112],
#        ...,
#        [0.88880158, 0.11119842],
#        [0.8946743 , 0.1053257 ],
#        [0.89680809, 0.10319191]])

# %%
obj.find_threshold(th=0.2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# _catboost.pyx in _catboost.get_float_feature()
#
# _catboost.pyx in _catboost._FloatOrNan()
#
# _catboost.pyx in _catboost._FloatOrNanFromString()
#
# TypeError: Cannot convert 'b'US'' to float
#
# During handling of the above exception, another exception occurred:
#
# CatBoostError                             Traceback (most recent call last)
# <ipython-input-55-79bb24c573d3> in <module>
# ----> 1 obj.find_threshold(th=0.2)
#
# ~/Desktop/private/riskitest/classifier.py in find_threshold(self, th, required_approval_rate)
#     133         clf = self.trained_model
#     134         if clf is not None:
# --> 135             model_probs = self.trained_model.predict_proba(self.X_test[self.model_features])
#     136             approval_rate = self.get_approval_rate(th, model_probs.tolist())
#     137             th_l, app_rate_l = [th], [approval_rate]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/catboost/core.py in predict_proba(self, data, ntree_start, ntree_end, thread_count, verbose)
#    4631                 with probability for every class for each object.
#    4632         """
# -> 4633         return self._predict(data, 'Probability', ntree_start, ntree_end, thread_count, verbose, 'predict_proba')
#    4634
#    4635
#
# ~/opt/anaconda3/lib/python3.8/site-packages/catboost/core.py in _predict(self, data, prediction_type, ntree_start, ntree_end, thread_count, verbose, parent_method_name)
#    2088         if verbose is None:
#    2089             verbose = False
# -> 2090         data, data_is_single_object = self._process_predict_input_data(data, parent_method_name, thread_count)
#    2091         self._validate_prediction_type(prediction_type)
#    2092
#
# ~/opt/anaconda3/lib/python3.8/site-packages/catboost/core.py in _process_predict_input_data(self, data, parent_method_name, thread_count, label)
#    2068         is_single_object = _is_data_single_object(data)
#    2069         if not isinstance(data, Pool):
# -> 2070             data = Pool(
#    2071                 data=[data] if is_single_object else data,
#    2072                 label=label,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/catboost/core.py in __init__(self, data, label, cat_features, text_features, embedding_features, column_description, pairs, delimiter, has_header, ignore_csv_quoting, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#     586                     )
#     587
# --> 588                 self._init(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#     589         super(Pool, self).__init__()
#     590
#
# ~/opt/anaconda3/lib/python3.8/site-packages/catboost/core.py in _init(self, data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#    1100             baseline = np.reshape(baseline, (samples_count, -1))
#    1101             self._check_baseline_shape(baseline, samples_count)
# -> 1102         self._init_pool(data, label, cat_features, text_features, embedding_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#    1103
#    1104
#
# _catboost.pyx in _catboost._PoolBase._init_pool()
#
# _catboost.pyx in _catboost._PoolBase._init_pool()
#
# _catboost.pyx in _catboost._PoolBase._init_features_order_layout_pool()
#
# _catboost.pyx in _catboost._set_features_order_data_pd_data_frame()
#
# _catboost.pyx in _catboost.create_num_factor_data()
#
# _catboost.pyx in _catboost.get_float_feature()
#
# CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=4]="US": Cannot convert 'b'US'' to float

# %%
obj.model_features
# Out:
# [False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True]

# %%
# Step 1
import pickle


class Polo:
    def __init__(self, name):
        self.name = name
        self.list_obj = []
        
    def add_item(self, item):
        self.list_obj.append(item)
        
        
        
Dorki = Polo(name='chava')        
        
        
        
        
        
        
        
        
        

Dorki.add_item('Thanks!')
Dorki.add_item('Brother!')
Dorki.list_obj

with open('company_data.pkl', 'wb') as output:
    pickle.dump(Dorki, output, pickle.HIGHEST_PROTOCOL)


# # Step 2
# with open('config.dictionary', 'wb') as config_dictionary_file:
#   # Step 3
#   pickle.dump(config_dictionary, config_dictionary_file)

# %%
with open('company_data.pkl', 'rb') as input:
    company1 = pickle.load(input)

# %%
company1.list_obj
# Out:
# ['Thanks!', 'Brother!']

# %%
config_dictionary = {'remote_hostname': 'google.com', 'remote_port': 80}
# Step 2
with open('config.dictionary', 'wb') as config_dictionary_file:
  # Step 3
  pickle.dump(config_dictionary, config_dictionary_file)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-4047ede0e8de> in <module>
# ----> 1 obj.X_train[obj.model_features]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2789         # Do we have a (boolean) 1d indexer?
#    2790         if com.is_bool_indexer(key):
# -> 2791             return self._getitem_bool_array(key)
#    2792
#    2793         # We are left with two options: a single key, and a collection of keys,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    2835             )
#    2836         elif len(key) != len(self.index):
# -> 2837             raise ValueError(
#    2838                 f"Item wrong length {len(key)} instead of {len(self.index)}."
#    2839             )
#
# ValueError: Item wrong length 21 instead of 152000.
